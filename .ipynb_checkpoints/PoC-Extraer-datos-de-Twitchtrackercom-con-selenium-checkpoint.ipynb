# %% [markdown]
# # Proff of Conncept: Extraer datos de Twitchtracker.com con Selenium

# %%
# Instalacion de librerias
#!pip install BeautifulSoup
# !pip install -U selenium
# !pip3 install -U webdriver-manager
# !pip install pandas

# %%
# LIBRERIAS

# Generales
import time
import requests
import urllib.request
import csv

# Gestion de datos
import pandas as pd

# Automatizacion
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
#from webdriver_manager.chrome import ChromeDriverManage

# %%
# Cosntantes

URL = 'https://twitchtracker.com/channels/ranking'

# %%
# Generador del veiculo driver addcion de atributos y parametros
opts = Options()
#opts.add_argument(" Extraer? Es necesario? ")

driver = webdriver.Chrome('./chromedriver.exe', options=opts)
# Out:
# C:\Users\Xoel\AppData\Local\Temp\ipykernel_7448\1837591573.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe', options=opts)

# %%
# Generador del veiculo driver addcion de atributos y parametros
opts = Options()
#opts.add_argument(" Extraer? Es necesario? ")

driver = webdriver.Chrome('./chromedriver.exe', options=opts)
# Out:
# C:\Users\Xoel\AppData\Local\Temp\ipykernel_7448\1837591573.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe', options=opts)

# %%
# Ir a pagina de Twitchtracker.com
driver.get(URL)

# %%
# Extraccion de datos 
href = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr')

for x in range (len(href)):
    print(href[x].get_attribute('innerHTML'))
    url_list = href[x].get_attribute('innerHTML')

#driver.quit()
# Out:
# <td>#1</td>
# <td>
# <a href="/auronplay" target="_blank">
# <img class="img-circle" src="https://static-cdn.jtvnw.net/jtv_user_pictures/ec898e4a-e0df-4dc0-a99d-7540c6dbe1e8-profile_image-300x300.png">
# </a>
# </td>
# <td><a href="/auronplay" target="_blank">auronplay</a></td>
# <td class="color-viewers"><span class="">132,057</span></td>
# <td class="color-streamed"><span>106.8</span><br><small>hours</small></td>
# <td class="color-viewersMax"><span class="">602,038</span></td>
# <td class="color-watched"><span class="">14.1M</span></td>
# <td class="active"><span class="rank-value">1</span></td>
# <td class="color-followers hidden-sm">
# +<span class="">338K</span>
# </td>
# <td class="color-followers hidden-sm"><span class="">13.8M</span></td>
# <td class="color-views hidden-sm"><span class="">263M</span></td>
#
#
# <td>#2</td>
# <td>
# <a href="/xqc" target="_blank">
# ...
