# %% [markdown]
# # Extraer los Top1000 Streamers de Twitch de https://twitchtracker.com/channels/ranking

# %%
# Instalacion de librerias
#!pip install BeautifulSoup
# !pip install -U selenium
# !pip3 install -U webdriver-manager
# !pip install pandas
# Out:
# Requirement already satisfied: selenium in c:\users\xoel\anaconda3\lib\site-packages (4.4.3)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\xoel\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\xoel\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\xoel\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\xoel\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\xoel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\xoel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\xoel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\xoel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\xoel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\xoel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\xoel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\xoel\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\xoel\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\xoel\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\xoel\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: webdriver-manager in c:\users\xoel\anaconda3\lib\site-packages (3.8.3)
# Requirement already satisfied: python-dotenv in c:\users\xoel\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: tqdm in c:\users\xoel\anaconda3\lib\site-packages (from webdriver-manager) (4.64.0)
# Requirement already satisfied: requests in c:\users\xoel\anaconda3\lib\site-packages (from webdriver-manager) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xoel\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\xoel\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\xoel\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xoel\anaconda3\lib\site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\xoel\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.4)
# Requirement already satisfied: pandas in c:\users\xoel\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\xoel\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\xoel\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\xoel\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\xoel\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# LIBRERIAS

# Generales
import time
import requests
import urllib.request
import csv

# Gestion de datos
import pandas as pd

# Automatizacion
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
#from webdriver_manager.chrome import ChromeDriverManage

# %%
# Cosntantes

URL = 'https://twitchtracker.com/channels/ranking'

# %%
# Generador del veiculo driver addcion de atributos y parametros
opts = Options()

# Seleccionar el driver
driver = webdriver.Chrome('./chromedriver.exe', options=opts)

# Maximizador de ventada del navegador web
driver.maximize_window()
# Out:
# C:\Users\Xoel\AppData\Local\Temp\ipykernel_17536\4114965669.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe', options=opts)

# %%
# Ir a pagina de Twitchtracker.com
driver.get(URL)

# %%
# Extraccion de datos 
#href = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr')

#for x in range (len(href)):
#    print(href[x].get_attribute('innerHTML'))
#    url_list = href[x].get_attribute('innerHTML')

# %%
rankins = driver.find_elements(By.XPATH, '/html/body/div[2]/div[2]/div[2]/table/tbody/tr')
for rank in rankins:
    print(rank.text)
# Out:
# #1 AURONPLAY 132,057 106.8
# hours 602,038 14.1M 1 +338K 13.8M 263M
# #2 XQC 59,226 283.3
# hours 278,176 16.8M 2 +72.3K 11.1M 525M
# #3 ELSPREEN 87,673 146.3
# hours 200,921 12.8M 3 +594K 5.37M 32.9M
# #4 KAICENAT 52,748 236.6
# hours 132,866 12.5M 4 +272K 2.02M 9.15M
# #5 IBAI 58,740 129.5
# hours 3,356,074 7.61M 5 +217K 11.6M 359M
# #6 LEC 60,064 114.9
# hours 400,312 6.90M 6 +44.5K 1.80M 149M
# #7 TARIK 45,261 187.8
# hours 187,886 8.50M 7 +111K 2.24M 93.3M
# #8 ROCKETLEAGUE 78,657 50.2
# hours 259,144 3.94M 8 +45.6K 3.73M 312M
# #9 ELMARIANA 56,161 118.6
# hours 128,442 6.66M 9 +429K 5.47M 33.3M
# #10 LCK_KOREA 53,663 126.1
# hours 623,617 6.76M 10 +22.4K 1.37M 408M
# #11 ADINROSS 59,366 92.1
# hours 254,923 5.47M 11 +94.9K 6.45M 52.4M
# #12 VALORANT 37,411 207
# hours 344,755 7.74M 12 +262K 3.33M 129M
# #13 PAULINHOLOKOBR 61,939 72.2
# hours 149,938 4.47M 13 +254K 1.01M 86.0K
#
# #14 BLASTPREMIER 50,585 103.7
# hours 270,934 5.25M 14 +53.2K 1.37M 114M
# #15 TRAINWRECKSTV 30,547 251.6
# hours 82,731 7.69M 15 +41.5K 2.07M 98.5M
# #16 LCS 32,799 219.6
# hours 400,429 7.20M 16 +54.6K 1.87M 167M
# #17 LOUD_CORINGA 45,256 109.6
# hours 307,450 4.96M 17 +80.1K 3.46M 50.8M
# #18 NIX 47,709 97.2
# hours 150,020 4.64M 18 +45.5K 315K 18.7M
# #19 ESL_DOTA2 55,461 65
# hours 263,970 3.60M 19 +26.0K 648K 93.1M
# #20 FPS_SHAKA 23,760 319.4
# hours 73,274 7.59M 20 +23.4K 938K 136M
# #21 ELIASN97 33,389 184.7
# hours 189,931 6.17M 21 +48.4K 1.18M 23.3M
# #22 GAULES 12,187 715.6
# hours 707,648 8.72M 22 +22.6K 3.62M 405M
# #23 RTAINJAPAN 42,546 104.5
# hours 182,595 4.45M 23 +25.9K 277K 17.9M
# #24 HASANABI 32,578 172.8
# hours 226,974 5.63M 24 +33.2K 2.17M 114M
# #25 JUANSGUARNIZO 35,927 142.1
# hours 409,967 5.11M 25 +303K 8.98M 168M
# #26 ESL_CSGO 19,439 361.8
# hours 562,080 7.03M 26 +37.6K 5.56M 770M
#
# #27 ROSHTEIN 23,308 280.1
# hours 84,977 6.53M 27 +31.9K 1.07M 94.7M
# #28 LCK 50,280 61.6
# hours 307,586 3.10M 28 +30.4K 1.51M 143M
# #29 PGL_DOTA2 38,071 119.6
# hours 161,982 4.55M 29 +37.3K 300K 38.0M
# #30 RUBIUS 34,834 126.1
# hours 372,079 4.39M 30 +184K 12.7M 273M
# #31 ILLOJUAN 34,412 114.3
# hours 172,186 3.93M 31 +122K 2.49M 72.0M
# #32 CBLOL 42,720 65.7
# hours 281,184 2.81M 32 +20.6K 1.49M 233M
# #33 STYLISHNOOB4 16,130 374.8
# hours 112,628 6.05M 33 +30.0K 868K 129M
# #34 SHROUD 25,698 181.2
# hours 516,289 4.66M 34 +83.6K 10.3M 571M
# #35 NICKMERCS 24,135 193.8
# hours 371,232 4.68M 35 +25.2K 6.57M 223M
# #36 MONTANABLACK88 41,734 52.2
# hours 194,927 2.18M 36 +51.4K 4.65M 156M
# #37 MIZKIF 32,902 96.2
# hours 192,216 3.16M 37 +15.2K 2.10M 103M
# #38 CASIMITO 26,903 143.7
# hours 534,644 3.87M 38 +87.2K 2.74M 37.8M
# #39 QUACKITYTOO 48,478 18.5
# hours 140,697 894K 39 +175K 2.90M 3.51M
#
# #40 LPL 28,252 109.9
# hours 149,720 3.10M 40 +29.1K 897K 110M
# #41 OTPLOL_ 7,827 719.1
# hours 204,072 5.63M 41 +8.7K 574K 100.0M
# #42 加藤純一です 22,512 165.9
# hours 241,593 3.74M 42 +12.7K 653K 38.4M
# #43 ELRAENN 27,271 113.4
# hours 163,915 3.09M 43 +112K 3.53M 101M
# #44 LOLTYLER1 18,126 227.7
# hours 368,484 4.13M 44 +20.8K 5.06M 301M
# #45 VALORANT_JPN 28,448 96.8
# hours 113,833 2.75M 45 +21.9K 344K 23.4M
# #46 BRUCEDROPEMOFF 33,358 60.7
# hours 69,077 2.02M 46 +93.6K 963K 7.84M
# #47 LUQUET4 20,399 177.2
# hours 92,525 3.61M 47 +142K 704K 4.45M
# #48 SUMMIT1G 12,342 358.8
# hours 310,998 4.43M 48 +4.1K 6.12M 505M
# #49 SODAPOPPIN 18,634 193.6
# hours 110,052 3.61M 49 +8.8K 8.81M 398M
# #50 한동숙 17,772 198.6
# hours 58,017 3.53M 50 +7.9K 512K 140M

# %%
# Extraccion de datos2

# Numero posicion del Stramer
#numero = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[1]')
# URL de imagen circular del Streamer
imagen = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[2]')
# Nombre del Streamer
nombres_streamer = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[3]')
# Promedio de viewer
avg_viewers = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[4]')
# Tiempo Streameado
time_streamed = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[5]')
# Espectadores de todos los tiempos
all_time_peak_viewers = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[6]')
# Horas vistas
hours_watched = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[7]')
# Posicion en el anking
rank = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[8]')
# Seguidores ganados
followers_gained = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[9]')
# Total de seguidores
total_followers = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[10]')
# Total de viewers
total_views = driver.find_elements(By.XPATH, '//*[@id="channels"]/tbody/tr/td[11]')
# Raw information
#raw_data = driver.find_elements(By.XPATH, '/html/body/div[2]/div[2]/div[2]/table/tbody/tr')

#//*[@id="channels"]/tbody/tr[2]/td[1]

#//*[@id="channels"]/thead[1]/tr/th[1]


data_results=[]

for item in range(len(rank)):
    temporal_data={
                    #'Numero': numero[item].text,
                    'URL imagen Streamer': imagen[item].get_attribute('innerHTML'),
                    'Nombres Streamers': nombres_streamer[item].text,
                    'AVG viewers': avg_viewers[item].text,
                    'Time Streamed': time_streamed[item].text,
                    'All time peak viewers': all_time_peak_viewers[item].text,
                    'Hours watched': hours_watched[item].text,
                    'Rank': rank[item].text,
                    'Followers gained': followers_gained[item].text,
                    'Total followers': total_followers[item].text,
                    'Total views': total_views[item].text,
                    #'Raw data': raw_data[item].text,
                    }
    data_results.append(temporal_data)

# %%
df_data = pd.DataFrame(data_results)
# Pasar datos por pantalla
df_data
# Out:
#                                   URL imagen Streamer Nombres Streamers  \
# 0   \n<a href="/auronplay" target="_blank">\n<img ...         AURONPLAY
# 1   \n<a href="/xqc" target="_blank">\n<img class=...               XQC
# 2   \n<a href="/elspreen" target="_blank">\n<img c...          ELSPREEN
# 3   \n<a href="/kaicenat" target="_blank">\n<img c...          KAICENAT
# 4   \n<a href="/ibai" target="_blank">\n<img class...              IBAI
# 5   \n<a href="/lec" target="_blank">\n<img class=...               LEC
# 6   \n<a href="/tarik" target="_blank">\n<img clas...             TARIK
# 7   \n<a href="/rocketleague" target="_blank">\n<i...      ROCKETLEAGUE
# 8   \n<a href="/elmariana" target="_blank">\n<img ...         ELMARIANA
# 9   \n<a href="/lck_korea" target="_blank">\n<img ...         LCK_KOREA
# 10  \n<a href="/adinross" target="_blank">\n<img c...          ADINROSS
# 11  \n<a href="/valorant" target="_blank">\n<img c...          VALORANT
# 12  \n<a href="/paulinholokobr" target="_blank">\n...    PAULINHOLOKOBR
# 13  \n<a href="/blastpremier" target="_blank">\n<i...      BLASTPREMIER
# 14  \n<a href="/trainwreckstv" target="_blank">\n<...     TRAINWRECKSTV
# 15  \n<a href="/lcs" target="_blank">\n<img class=...               LCS
# 16  \n<a href="/loud_coringa" target="_blank">\n<i...      LOUD_CORINGA
# 17  \n<a href="/nix" target="_blank">\n<img class=...               NIX
# 18  \n<a href="/esl_dota2" target="_blank">\n<img ...         ESL_DOTA2
# 19  \n<a href="/fps_shaka" target="_blank">\n<img ...         FPS_SHAKA
# 20  \n<a href="/eliasn97" target="_blank">\n<img c...          ELIASN97
# 21  \n<a href="/gaules" target="_blank">\n<img cla...            GAULES
# 22  \n<a href="/rtainjapan" target="_blank">\n<img...        RTAINJAPAN
# 23  \n<a href="/hasanabi" target="_blank">\n<img c...          HASANABI
# 24  \n<a href="/juansguarnizo" target="_blank">\n<...     JUANSGUARNIZO
# 25  \n<a href="/esl_csgo" target="_blank">\n<img c...          ESL_CSGO
# 26  \n<a href="/roshtein" target="_blank">\n<img c...          ROSHTEIN
# 27  \n<a href="/lck" target="_blank">\n<img class=...               LCK
# 28  \n<a href="/pgl_dota2" target="_blank">\n<img ...         PGL_DOTA2
# 29  \n<a href="/rubius" target="_blank">\n<img cla...            RUBIUS
# 30  \n<a href="/illojuan" target="_blank">\n<img c...          ILLOJUAN
# 31  \n<a href="/cblol" target="_blank">\n<img clas...             CBLOL
# 32  \n<a href="/stylishnoob4" target="_blank">\n<i...      STYLISHNOOB4
# 33  \n<a href="/shroud" target="_blank">\n<img cla...            SHROUD
# 34  \n<a href="/nickmercs" target="_blank">\n<img ...         NICKMERCS
# 35  \n<a href="/montanablack88" target="_blank">\n...    MONTANABLACK88
# 36  \n<a href="/mizkif" target="_blank">\n<img cla...            MIZKIF
# 37  \n<a href="/casimito" target="_blank">\n<img c...          CASIMITO
# 38  \n<a href="/quackitytoo" target="_blank">\n<im...       QUACKITYTOO
# 39  \n<a href="/lpl" target="_blank">\n<img class=...               LPL
# 40  \n<a href="/otplol_" target="_blank">\n<img cl...           OTPLOL_
# 41  \n<a href="/kato_junichi0817" target="_blank">...            加藤純一です
# 42  \n<a href="/elraenn" target="_blank">\n<img cl...           ELRAENN
# 43  \n<a href="/loltyler1" target="_blank">\n <img...         LOLTYLER1
# 44  \n<a href="/valorant_jpn" target="_blank">\n<i...      VALORANT_JPN
# 45  \n<a href="/brucedropemoff" target="_blank">\n...    BRUCEDROPEMOFF
# 46  \n<a href="/luquet4" target="_blank">\n<img cl...           LUQUET4
# 47  \n<a href="/summit1g" target="_blank">\n<img c...          SUMMIT1G
# 48  \n<a href="/sodapoppin" target="_blank">\n<img...        SODAPOPPIN
# 49  \n<a href="/handongsuk" target="_blank">\n<img...               한동숙
#
#    AVG viewers Time Streamed All time peak viewers Hours watched Rank  \
# 0      132,057  106.8\nhours               602,038         14.1M    1
# 1       59,226  283.3\nhours               278,176         16.8M    2
# 2       87,673  146.3\nhours               200,921         12.8M    3
# 3       52,748  236.6\nhours               132,866         12.5M    4
# 4       58,740  129.5\nhours             3,356,074         7.61M    5
# 5       60,064  114.9\nhours               400,312         6.90M    6
# 6       45,261  187.8\nhours               187,886         8.50M    7
# 7       78,657   50.2\nhours               259,144         3.94M    8
# 8       56,161  118.6\nhours               128,442         6.66M    9
# 9       53,663  126.1\nhours               623,617         6.76M   10
# 10      59,366   92.1\nhours               254,923         5.47M   11
# 11      37,411    207\nhours               344,755         7.74M   12
# 12      61,939   72.2\nhours               149,938         4.47M   13
# 13      50,585  103.7\nhours               270,934         5.25M   14
# 14      30,547  251.6\nhours                82,731         7.69M   15
# 15      32,799  219.6\nhours               400,429         7.20M   16
# 16      45,256  109.6\nhours               307,450         4.96M   17
# 17      47,709   97.2\nhours               150,020         4.64M   18
# 18      55,461     65\nhours               263,970         3.60M   19
# 19      23,760  319.4\nhours                73,274         7.59M   20
# 20      33,389  184.7\nhours               189,931         6.17M   21
# 21      12,187  715.6\nhours               707,648         8.72M   22
# 22      42,546  104.5\nhours               182,595         4.45M   23
# 23      32,578  172.8\nhours               226,974         5.63M   24
# 24      35,927  142.1\nhours               409,967         5.11M   25
# 25      19,439  361.8\nhours               562,080         7.03M   26
# 26      23,308  280.1\nhours                84,977         6.53M   27
# 27      50,280   61.6\nhours               307,586         3.10M   28
# 28      38,071  119.6\nhours               161,982         4.55M   29
# 29      34,834  126.1\nhours               372,079         4.39M   30
# 30      34,412  114.3\nhours               172,186         3.93M   31
# 31      42,720   65.7\nhours               281,184         2.81M   32
# 32      16,130  374.8\nhours               112,628         6.05M   33
# 33      25,698  181.2\nhours               516,289         4.66M   34
# 34      24,135  193.8\nhours               371,232         4.68M   35
# 35      41,734   52.2\nhours               194,927         2.18M   36
# 36      32,902   96.2\nhours               192,216         3.16M   37
# 37      26,903  143.7\nhours               534,644         3.87M   38
# 38      48,478   18.5\nhours               140,697          894K   39
# 39      28,252  109.9\nhours               149,720         3.10M   40
# 40       7,827  719.1\nhours               204,072         5.63M   41
# 41      22,512  165.9\nhours               241,593         3.74M   42
# 42      27,271  113.4\nhours               163,915         3.09M   43
# 43      18,126  227.7\nhours               368,484         4.13M   44
# 44      28,448   96.8\nhours               113,833         2.75M   45
# 45      33,358   60.7\nhours                69,077         2.02M   46
# 46      20,399  177.2\nhours                92,525         3.61M   47
# 47      12,342  358.8\nhours               310,998         4.43M   48
# 48      18,634  193.6\nhours               110,052         3.61M   49
# 49      17,772  198.6\nhours                58,017         3.53M   50
#
#    Followers gained Total followers Total views
# 0             +338K           13.8M        263M
# 1            +72.3K           11.1M        525M
# 2             +594K           5.37M       32.9M
# 3             +272K           2.02M       9.15M
# 4             +217K           11.6M        359M
# 5            +44.5K           1.80M        149M
# 6             +111K           2.24M       93.3M
# 7            +45.6K           3.73M        312M
# 8             +429K           5.47M       33.3M
# 9            +22.4K           1.37M        408M
# 10           +94.9K           6.45M       52.4M
# 11            +262K           3.33M        129M
# 12            +254K           1.01M       86.0K
# 13           +53.2K           1.37M        114M
# 14           +41.5K           2.07M       98.5M
# 15           +54.6K           1.87M        167M
# 16           +80.1K           3.46M       50.8M
# 17           +45.5K            315K       18.7M
# 18           +26.0K            648K       93.1M
# 19           +23.4K            938K        136M
# 20           +48.4K           1.18M       23.3M
# 21           +22.6K           3.62M        405M
# 22           +25.9K            277K       17.9M
# 23           +33.2K           2.17M        114M
# 24            +303K           8.98M        168M
# 25           +37.6K           5.56M        770M
# 26           +31.9K           1.07M       94.7M
# 27           +30.4K           1.51M        143M
# 28           +37.3K            300K       38.0M
# 29            +184K           12.7M        273M
# 30            +122K           2.49M       72.0M
# 31           +20.6K           1.49M        233M
# 32           +30.0K            868K        129M
# 33           +83.6K           10.3M        571M
# 34           +25.2K           6.57M        223M
# 35           +51.4K           4.65M        156M
# 36           +15.2K           2.10M        103M
# 37           +87.2K           2.74M       37.8M
# 38            +175K           2.90M       3.51M
# 39           +29.1K            897K        110M
# 40            +8.7K            574K      100.0M
# 41           +12.7K            653K       38.4M
# 42            +112K           3.53M        101M
# 43           +20.8K           5.06M        301M
# 44           +21.9K            344K       23.4M
# 45           +93.6K            963K       7.84M
# 46            +142K            704K       4.45M
# 47            +4.1K           6.12M        505M
# 48            +8.8K           8.81M        398M
# 49            +7.9K            512K        140M
